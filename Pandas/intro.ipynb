# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.2

# %%
import pandas as pd

# print(pd.__version__)

my_data_set = {
    'car': ["BMW", "Volvo", "Ford"],
    'passings': [3, 7, 2]
}

df = pd.DataFrame(my_data_set)

df
# Out:
#      car  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# Series
